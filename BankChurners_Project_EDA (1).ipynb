# %% [markdown]
# ### Introduction
# ##### A manager at the bank is disturbed with more and more customers leaving their credit card services . They would really appreciate if one could predict for them who is gonna get churned so they can proactively go to the customer to provide them better services and turn customers' decisions in the opposite direction.

# %% [markdown]
# ### 1. Business Understanding

# %% [raw]
# 1.1. Xác định mục tiêu:
# Tìm ra nguyên nhân khách hàng rời bỏ dịch vụ thẻ tín dụng
#       Nghiên cứu nguyên nhân
#       Tại sao khách hàng rời bỏ?
#       Những phân khúc khách hàng nào có nguy cơ churn cao nhất?
#       Churn ảnh hưởng đến doanh thu và lợi nhuận như thế nào?
# Cách giải quyết tình trạng
#       Làm thế nào để giữ chân khách hàng có nguy cơ rời bỏ?
#       Chi phí giữ chân khách hàng là bao nhiêu và liệu có hiệu quả không?
#       Các phương pháp đánh giá tác động kinh doanh của mô hình churn là gì?

# %% [markdown]
# ## 2. Data Understanding

# %%
2.1.Bộ dữ liệu này là hồ sơ tiêu dùng lịch sử của người dùng thẻ tín dụng của một ngân hàng nước ngoài trong hai năm từ 2015-2017
bao gồm thông tin nhân khẩu học, thông tin kế toán và thông tin hành vi của người dùng.
2.2. Bộ dữ liệu có 10127 records của các khách hàng riêng biệt với 22 features

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\ADMIN\Videos\FDA\BankChurners\BankChurners.csv")
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
df.shape
# Out:
# (10127, 23)

# %%
df.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'],
#       dtype='object')

# %%
df['Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'].value_counts()
# Out:
# 0.999890    631
# 0.999940    551
# 0.999810    478
# 0.999900    452
# 0.999930    394
#            ...
# 0.000967      1
# 0.003262      1
# 0.009370      1
# 0.016310      1
# 0.003377      1
# Name: Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2, Length: 640, dtype: int64

# %% [raw]
# Hai cột cuối này có vẻ là kết quả của một mô hình Naive Bayes trước đó và không chứa thông tin gốc về khách hàng. Chúng không cần thiết cho việc phân tích hoặc xây dựng mô hình mới, vì chúng đã được sinh ra dựa trên các thuộc tính khác.
# => Chúng ta sẽ drop 2 cột này đi
# Và cột CLIENTNUM sẽ không có ý nghĩa nói cách khác nó sẽ không ảnh hưởng đến customer churn -> drop cột này

# %%
# drop naive Bayes model predictions
df.drop(columns = ['Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
       'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'], inplace = True)
df.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio'],
#       dtype='object')

# %%
# The label of this dataset is the #columns name 'Attrition_Flag' => Rename thành label
df.rename(columns ={'Attrition_Flag':'Label'},inplace = True)
df
# Out:
#        CLIENTNUM              Label  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %% [markdown]
# ## 3.Data Exploration

# %% [markdown]
# ##### 3.1 Attrition_Flag

# %%
#Calculating the percentage of Attrited Customers and Existing customer

attrited_percent = df["Label"].value_counts()[1] / len(df["Label"])
exist_percent = df["Label"].value_counts()[0] / len(df["Label"])

print("The percentage of Attrited Customers in this dataset: ", "{:.2%}".format(attrited_percent))
print("The percentage of Existing Customers in this dataset: ", "{:.2%}".format(exist_percent))
# Out:
# The percentage of Attrited Customers in this dataset:  16.07%
# The percentage of Existing Customers in this dataset:  83.93%

# %%
sns.countplot(x = df['Label'],data = df)
# Out:
# <Axes: xlabel='Label', ylabel='count'>

# %% [raw]
# => Có sự unbalance trong tập target

# %% [markdown]
# #### 3.2.Customer_Age

# %%
plt.figure(figsize=(10,5))
sns.countplot(x ='Customer_Age', hue = 'Label', data = df, palette = "RdBu_r")
# Out:
# <Axes: xlabel='Customer_Age', ylabel='count'>

# %% [raw]
# => Khách hàng rời bỏ và đang sử dụng thẻ tín dụng ngân hàng chủ yếu nằm trong độ tuổi 43-50

# %% [markdown]
# ## 3.3. Gender

# %%
plt.figure(figsize=(10,5))
sns.countplot(x ='Gender', hue = 'Label', data = df, palette = "RdBu_r")
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
=> Tỷ lệ nữ rời bỏ cao hơn nam

# %% [markdown]
# ##### 3.5.Dependent_count

# %%
plt.figure(figsize=(10,5))
sns.countplot(x ='Education_Level', hue = 'Label', data = df, palette = "RdBu_r")
# Out:
# <Axes: xlabel='Education_Level', ylabel='count'>

# %%
education_counts = df['Education_Level'].value_counts()
plt.pie(education_counts, labels=education_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Proportion of Education Level')
plt.gca().set_aspect('equal')

# %% [raw]
#  => Nếu chúng ta xem unknown này là uneducated thì có hơn 70% khách hàng có formal education

# %% [markdown]
# ##### 3.6. Marital_Status

# %%
plt.figure(figsize=(10,5))
sns.countplot(x ='Marital_Status', hue = 'Label', data = df, palette = "RdBu_r")
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %% [markdown]
# => Lượng khách hàng sử dụng thẻ tín dụng chủ yếu là Married
# Số lượng khách hàng rời bỏ married và single có tỷ lệ ngang nhau

# %% [markdown]
# #### 3.7.Income_Category

# %%
plt.figure(figsize=(10,5))
sns.countplot(x ='Income_Category', hue = 'Label', data = df, palette = "RdBu_r")
# Out:
# <Axes: xlabel='Income_Category', ylabel='count'>

# %% [raw]
# Khách hàng có thu nhập ít hơn $40K chiếm phần lớn và Khách hàng với income từ 40k-60k có thể là khách hàng tiềm năng cho ngân hàng
# Nhóm có thu nhập càng thấp càng dễ rời bỏ dịch vụ

# %% [markdown]
# ### 3.8.Card_Category

# %%
plt.figure(figsize=(10,5))
sns.countplot(x ='Card_Category', hue = 'Label', data = df, palette = "RdBu_r")
# Out:
# <Axes: xlabel='Card_Category', ylabel='count'>

# %% [markdown]
# => Loại thẻ được sử dụng nhiều nhất là Blue

# %% [markdown]
# #### 3.9.Months_on_book

# %%
plt.figure(figsize=(10,5))
sns.countplot(x ='Months_on_book', hue = 'Label', data = df, palette = "RdBu_r")
# Out:
# <Axes: xlabel='Months_on_book', ylabel='count'>

# %% [markdown]
# #### 3.10 .Total_relationship_count

# %%
plt.figure(figsize=(10,5))
sns.countplot(x ='Total_Relationship_Count', hue = 'Label', data = df, palette = "RdBu_r")
# Out:
# <Axes: xlabel='Total_Relationship_Count', ylabel='count'>

# %% [markdown]
# #### 3.11.Months_Inactive_12_mon

# %%
plt.figure(figsize=(10,5))
sns.countplot(x ='Months_Inactive_12_mon', data = df, color= "lightblue")
# Out:
# <Axes: xlabel='Months_Inactive_12_mon', ylabel='count'>

# %% [raw]
# => Thường thì sau 2-3 tháng  không có bất kì giao dịch

# %%
plt.figure(figsize=(10,5))
sns.countplot(x ='Contacts_Count_12_mon', data = df, color= "lightblue")
# Out:
# <Axes: xlabel='Contacts_Count_12_mon', ylabel='count'>

# %% [raw]
# => Khách hàng được liên hệ trung bình 2,4 lần

# %% [markdown]
# #### 3.9.Credit_Limit

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, figsize=(12, 7))

sns.boxplot(x=df['Credit_Limit'], ax=ax1)
ax1.set_title('Credit Limit Box Plot')

ax2.hist(df['Credit_Limit'], bins=30, color='blue', edgecolor='black')
ax2.set_title('Credit Limit Histogram')

fig.suptitle('Distribution of the Credit Limit', fontsize=16)

plt.tight_layout(rect=[0, 0, 1, 0.96])  
plt.show()

# %%
=> Limit của credit card nằm từ 2500 -> 5000

# %% [markdown]
# ## 4.Data Processing

# %%
df.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  1.012700e+04  10127.000000     10127.000000    10127.000000
# mean   7.391776e+08     46.325960         2.346203       35.928409
# std    3.690378e+07      8.016814         1.298908        7.986416
# min    7.080821e+08     26.000000         0.000000       13.000000
# 25%    7.130368e+08     41.000000         1.000000       31.000000
# 50%    7.179264e+08     46.000000         2.000000       36.000000
# 75%    7.731435e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# ...

# %%
df.dtypes
# Out:
# CLIENTNUM                     int64
# Label                        object
# Customer_Age                  int64
# Gender                       object
# Dependent_count               int64
# Education_Level              object
# Marital_Status               object
# Income_Category              object
# Card_Category                object
# Months_on_book                int64
# Total_Relationship_Count      int64
# Months_Inactive_12_mon        int64
# Contacts_Count_12_mon         int64
# Credit_Limit                float64
# Total_Revolving_Bal           int64
# Avg_Open_To_Buy             float64
# Total_Amt_Chng_Q4_Q1        float64
# Total_Trans_Amt               int64
# Total_Trans_Ct                int64
# Total_Ct_Chng_Q4_Q1         float64
# Avg_Utilization_Ratio       float64
# dtype: object

# %% [raw]
# There are three main types here: object, int64, float64.

# %%
# make a copy dataframe
df_cln = df.copy()
df_cln.head()
# Out:
#    CLIENTNUM              Label  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# ...

# %%
df_cln['Label'].value_counts()
# Out:
# Existing Customer    8500
# Attrited Customer    1627
# Name: Label, dtype: int64

# %% [markdown]
# ### Xử lý missing values!

# %%
for col in df_cln.columns:
    print(col)
    print(df_cln[col].unique())
# Out:
# CLIENTNUM
# [768805383 818770008 713982108 ... 716506083 717406983 714337233]
# Label
# ['Existing Customer' 'Attrited Customer']
# Customer_Age
# [45 49 51 40 44 32 37 48 42 65 56 35 57 41 61 47 62 54 59 63 53 58 55 66
#  50 38 46 52 39 43 64 68 67 60 73 70 36 34 33 26 31 29 30 28 27]
# Gender
# ['M' 'F']
# Dependent_count
# [3 5 4 2 0 1]
# Education_Level
# ['High School' 'Graduate' 'Uneducated' 'Unknown' 'College' 'Post-Graduate'
#  'Doctorate']
# Marital_Status
# ['Married' 'Single' 'Unknown' 'Divorced']
# Income_Category
# ['$60K - $80K' 'Less than $40K' '$80K - $120K' '$40K - $60K' '$120K +'
#  'Unknown']
# Card_Category
# ['Blue' 'Gold' 'Silver' 'Platinum']
# Months_on_book
# [39 44 36 34 21 46 27 31 54 30 48 37 56 42 49 33 28 38 41 43 45 52 40 50
#  35 47 32 20 29 25 53 24 55 23 22 26 13 51 19 15 17 18 16 14]
# Total_Relationship_Count
# [5 6 4 3 2 1]
# Months_Inactive_12_mon
# [1 4 2 3 6 0 5]
# Contacts_Count_12_mon
# [3 2 0 1 4 5 6]
# Credit_Limit
# ...

# %%
df_cln.isna().sum().sum()
# Out:
# 0

# %%
df_cln.duplicated().sum()
# Out:
# 0

# %% [raw]
# Mặc dù chúng ta ko tìm thấy giá trị null nào hay missing value nhưng ở trong đây có một số cột chứa giá trị Unknown
# => Drop các hàng của có giá trị Unknown vì chúng chỉ chiếm phần nhỏ trong dataset

# %%
df_cln['Education_Level'].value_counts()
# Out:
# Graduate         3128
# High School      2013
# Unknown          1519
# Uneducated       1487
# College          1013
# Post-Graduate     516
# Doctorate         451
# Name: Education_Level, dtype: int64

# %%
df_cln['Marital_Status'].value_counts()
# Out:
# Married     4687
# Single      3943
# Unknown      749
# Divorced     748
# Name: Marital_Status, dtype: int64

# %%
df_cln['Income_Category'].value_counts()
# Out:
# Less than $40K    3561
# $40K - $60K       1790
# $80K - $120K      1535
# $60K - $80K       1402
# Unknown           1112
# $120K +            727
# Name: Income_Category, dtype: int64

# %%
# drop the row have unknown value
for i in df_cln.columns:
    df_cln = df_cln[df_cln[i] != 'Unknown']
df_cln.head()
# Out:
#    CLIENTNUM              Label  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 4  709106358  Existing Customer            40      M                3
# 5  713061558  Existing Customer            44      M                2
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
# 5        Graduate        Married     $40K - $60K          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# ...

# %%
df.shape
# Out:
# (10127, 21)

# %%
df_cln.shape
# Out:
# (7081, 21)

# %% [raw]
# Có 2 loại trong dataset: categorical and numberical.
# Chúng ta sẽ chuyển các dữ liệu dạng category sang dạng số để sau dễ chạy model vì một ML model không thể làm việc với chữ
# ta sẽ sử dụng encode label để chuyển

# %%
# print all object type
columns = df.select_dtypes(exclude = 'number')

for col in columns:
    print(col)
    print(df_cln[col].unique())
# Out:
# Label
# ['Existing Customer' 'Attrited Customer']
# Gender
# ['M' 'F']
# Education_Level
# ['High School' 'Graduate' 'Uneducated' 'College' 'Post-Graduate'
#  'Doctorate']
# Marital_Status
# ['Married' 'Single' 'Divorced']
# Income_Category
# ['$60K - $80K' 'Less than $40K' '$80K - $120K' '$40K - $60K' '$120K +']
# Card_Category
# ['Blue' 'Gold' 'Silver' 'Platinum']

# %%
# encoder
categories_encoded = {
                     'Label':{'Existing Customer': 0, 'Attrited Customer': 1},
                    'Gender':{'M':1,'F': 2},
                     'Education_Level':{'High School':1, 'Graduate':2 ,'Uneducated':3, 'College':4, 'Post-Graduate':5, 'Doctorate':6},
                    'Marital_Status':{'Married':1, 'Single':2, 'Divorced':3},
                    'Income_Category':{'$60K - $80K':1,'Less than $40K':2, '$80K - $120K':3, '$40K - $60K':4, '$120K +':5},
                    'Card_Category': {'Blue':1, 'Gold':2, 'Silver':3, 'Platinum':4}
}
df_enc = df_cln.replace(categories_encoded)
df_enc.head()
# Out:
#    CLIENTNUM  Label  Customer_Age  Gender  Dependent_count  Education_Level  \
# 0  768805383      0            45       1                3                1
# 1  818770008      0            49       2                5                2
# 2  713982108      0            51       1                3                2
# 4  709106358      0            40       1                3                3
# 5  713061558      0            44       1                2                2
#
#    Marital_Status  Income_Category  Card_Category  Months_on_book  ...  \
# 0               1                1              1              39  ...
# 1               2                2              1              44  ...
# 2               1                3              1              36  ...
# 4               1                1              1              21  ...
# 5               1                4              1              36  ...
#
#    Months_Inactive_12_mon  Contacts_Count_12_mon  Credit_Limit  \
# ...

# %%
df_enc['Label'].value_counts()
# Out:
# 0    5968
# 1    1113
# Name: Label, dtype: int64

# %%
df_enc.dtypes
# Out:
# CLIENTNUM                     int64
# Label                         int64
# Customer_Age                  int64
# Gender                        int64
# Dependent_count               int64
# Education_Level               int64
# Marital_Status                int64
# Income_Category               int64
# Card_Category                 int64
# Months_on_book                int64
# Total_Relationship_Count      int64
# Months_Inactive_12_mon        int64
# Contacts_Count_12_mon         int64
# Credit_Limit                float64
# Total_Revolving_Bal           int64
# Avg_Open_To_Buy             float64
# Total_Amt_Chng_Q4_Q1        float64
# Total_Trans_Amt               int64
# Total_Trans_Ct                int64
# Total_Ct_Chng_Q4_Q1         float64
# Avg_Utilization_Ratio       float64
# dtype: object

# %%
# heatmap
plt.subplots(figsize = (18,18))
sns.heatmap(df_enc.corr(), annot = True, linewidths = 0.2)
# Out:
# <Axes: >

# %% [raw]
# Một tương quan dương giữa x1 và x2 có nghĩa là khi x1 tăng thì x2 cũng tăng
# Một tương quan âm giữa x1 và x2 có nghĩa là khi x1 tăng thì x2 giảm

# %% [raw]
# Chúng ta chắc chắn phải loại bỏ Clientnum.Vì nó hoàn toàn không liên quan
#
# Tương quan cao giữa Total_Trans_Amt và Total_Trans_Ct. Ta có thể loại bỏ một hoặc kết hợp chúng thành một số tiền trung bình cho mỗi giao dịch.
# Months_on_book và Customer_Age có tương quan cao nhưng cả hai giá trị đều có thể chỉ ra xu hướng hao hụt.

# %%
plt.figure(figsize=(10,5))
sns.countplot(x ='Customer_Age', hue = 'Label', data = df_enc, palette = "RdBu_r")
# Out:
# <Axes: xlabel='Customer_Age', ylabel='count'>

# %%
sns.boxplot(x = 'Label', y = 'Customer_Age', hue = 'Label', palette = 'RdBu_r', data = df_enc)
# Out:
# <Axes: xlabel='Label', ylabel='Customer_Age'>

# %% [raw]
# Điều này cho thấy rằng:
# 1. Dữ liệu được thu thập tập trung vào khách hàng trung niên.
# 2. Không có nhiều sự khác biệt về phân bố độ tuổi giữa những người rời đi và những người ở lại

# %%
# With Months_on_book
plt.figure(figsize = (10,5))
sns.countplot(x = 'Months_on_book', hue ='Label', data = df_enc, palette = 'RdBu_r')
# Out:
# <Axes: xlabel='Months_on_book', ylabel='count'>

# %%
sns.boxplot(x = 'Label', y ='Months_on_book', hue = 'Label', palette = 'RdBu_r', data = df_enc)
# Out:
# <Axes: xlabel='Label', ylabel='Months_on_book'>

# %% [raw]
# Months_as_book tập trung cực kỳ nhiều vào 36 tháng! Có vẻ như họ đã thu thập hầu hết thông tin của khách hàng tại điểm kiểm tra 3 năm. chúng tôi sẽ muốn bỏ thông tin này đi, giữ lại thông tin này không có nhiều ý nghĩa. Thêm vào đó, biểu đồ cho thấy không có tác động quá lớn của months_on_books lên tỷ lệ hao hụt

# %%
plt.figure(figsize = (10,5))
sns.countplot(x = 'Total_Relationship_Count', hue = "Label", data = df_enc, palette = 'RdBu_r')
# Out:
# <Axes: xlabel='Total_Relationship_Count', ylabel='count'>

# %% [markdown]
# # Phân tích nguyên nhân dẫn đến Churn

# %% [markdown]
# #### Tạo ra bức tranh chân dung khách hàng
# #### Phân tích dữ liệu liên quan đến nhân khẩu học: Age, Gender, Income, Education Level, Marital Status,, Occupation, Geographic Location, Nationality, Ethnicity, Religion, Family Size

# %% [raw]
# Trong dataset này, dữ liệu liên quan đến nhân khẩu học bao gồm các cột: Customer_Age, Gender, Education_Level, Marital_Status, Income_Category, Card_category, Dependent_Count.Chúng ta sẽ phân tích chúng và nhận thấy rằng ngoài Customer_Age các cột còn lại đều có định dạng là category

# %%
num_cols = list(df_cln.select_dtypes(['int64','float64']))
cat_cols = list(df_cln.select_dtypes(['object']))

# %%
cat_cols
# Out:
# ['Label',
#  'Gender',
#  'Education_Level',
#  'Marital_Status',
#  'Income_Category',
#  'Card_Category']

# %%
# encoder label
categories_encoded = {'Label':{'Existing Customer': 0, 'Attrited Customer': 1}}
df_encl = df_cln.replace(categories_encoded)
df_encl.head()
# Out:
#    CLIENTNUM  Label  Customer_Age Gender  Dependent_count Education_Level  \
# 0  768805383      0            45      M                3     High School
# 1  818770008      0            49      F                5        Graduate
# 2  713982108      0            51      M                3        Graduate
# 4  709106358      0            40      M                3      Uneducated
# 5  713061558      0            44      M                2        Graduate
#
#   Marital_Status Income_Category Card_Category  Months_on_book  ...  \
# 0        Married     $60K - $80K          Blue              39  ...
# 1         Single  Less than $40K          Blue              44  ...
# 2        Married    $80K - $120K          Blue              36  ...
# 4        Married     $60K - $80K          Blue              21  ...
# 5        Married     $40K - $60K          Blue              36  ...
#
#    Months_Inactive_12_mon  Contacts_Count_12_mon  Credit_Limit  \
# ...

# %%
columns = ['Gender', 'Marital_Status', 'Card_Category','Education_Level']

fig, axes = plt.subplots(len(columns), 2, figsize=(20, 15))

for i, col in enumerate(columns):
    
    # Vẽ countplot
    ax1 = sns.countplot(x=col, hue='Label', data=df_encl, palette="RdBu_r", ax=axes[i, 0])
    for p in ax1.patches:
        ax1.annotate(format(p.get_height(), '.0f'), 
                     (p.get_x() + p.get_width() / 2., p.get_height()), 
                     ha='center', va='center', 
                     xytext=(0, 5), textcoords='offset points')
    
    # Vẽ barplot
    df_group_mean = df_encl.groupby([col]).agg(Attrition_Flag=('Label', 'mean')).reset_index()
    ax2 = sns.barplot(data=df_group_mean, x=col, y='Attrition_Flag', fill=True, alpha=1, errorbar=None, 
                      palette=('#54BAB9', '#E9DAC1','#F7ECDE'), ax=axes[i, 1])
    for p in ax2.patches:
        ax2.annotate(format(p.get_height(), '.2f'), 
                     (p.get_x() + p.get_width() / 2., p.get_height()), 
                     ha='center', va='center', 
                     xytext=(0, 5), textcoords='offset points')

# Hiển thị biểu đồ
plt.tight_layout()
plt.show()

# %%
# !pip install squarify

# %%
import squarify


df_group = df_encl.groupby(['Income_Category']).agg(num_user=('CLIENTNUM', 'count')).reset_index()

labels = df_group['Income_Category']


sizes = df_group['num_user']
colors = ['#ff6666', '#6699ff', '#66ff66', '#ffcc66', '#9999ff', '#ff99cc']

labels_with_sizes = [f'{label}\n{size}' for label, size in zip(labels, sizes)]

fig, ax = plt.subplots(1, 2, figsize=(18, 8))

squarify.plot(sizes=sizes, label=labels_with_sizes, color=colors, ax=ax[0], alpha=.8, text_kwargs={'fontsize':12, 'weight':'bold', 'fontfamily':'serif'})
ax[0].set_title('Income Distribution Treemap', fontsize=16, weight='bold')
ax[0].axis('off')

df_group_mean = df_encl.groupby(['Income_Category']).agg(Label_mean=('Label', 'mean')).reset_index()
sns.barplot(data=df_group_mean, x='Income_Category', y='Label_mean', fill=True, alpha=1, errorbar=None, ax=ax[1], palette=('#54BAB9', '#E9DAC1','#F7ECDE'))

# ax[1].set_xlabel(' ')
# ax[1].set_xlabel(' ')
# ax[1].set_ylabel(' ')
# ax[1].xaxis.set_tick_params(labelsize=14)
ax[1].tick_params(left=False, labelleft=False)
ax[1].set_ylabel('Income_Category', fontsize=16)    
ax[1].bar_label(ax[1].containers[0], size="12")
ax[1].grid(False)

plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Vẽ biểu đồ countplot 
sns.countplot(x='Customer_Age', hue='Label', data=df_encl, palette="RdBu_r", ax=axes[0])

# Vẽ biểu đồ boxplot 
sns.boxplot(data=df_encl, y='Customer_Age', x='Label', palette="RdBu_r", ax=axes[1])

plt.tight_layout()
plt.show()

# %%
# Dependent_count
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Vẽ biểu đồ countplot 
sns.countplot(x='Dependent_count', hue='Label', data=df_encl, palette="RdBu_r", ax=axes[0])

# Vẽ biểu đồ boxplot 
sns.boxplot(data=df_encl, y='Dependent_count', x='Label', palette="RdBu_r", ax=axes[1])


plt.tight_layout()
plt.show()

# %% [raw]
# Sau khi vẽ xong ta có thể đưa ra 1 số kết luận về chân dung khách hàng như sau:
# 1. Về giới tính: Nhìn chung khách hàng có sự cân bằng về mặt giới tính, tỷ lệ rời bỏ nữ cao hơn 0,03%
# 2. Về tình trạng hôn nhân: nhìn chung tỷ lệ rời bỏ ở các nhóm khách hàng ở đây không có nhiều cách biệt, nói cách khác tình trạng hôn nhân không ảnh hưởng nhiều tới quyết định rời bỏ của khách hàng
# 3.Về các loại thẻ: có đến 95% khách hàng sở hữu thẻ Blue , có lẽ do thu nhập thấp
# 4.về trình độ học vấn: Có sự phân bố khác rõ ràng về tỷ lệ rời bỏ ở các nhóm khách hàng, 50% khách hàng có bằng đại học trở lên (gần 20% có bằng trên đại học), số khách hàng còn lại học hết trung học hoặc không đi học, có 15% không rõ trình độ học vấn.
# 5.Về thu nhập, những người có thu nhập càng thấp thì càng dễ rời bỏ sử dụng dịch vụ. Và có đến 40% khách hàng có thu nhập ít hơn 40K/năm, chỉ có hơn 8% khách hàng có thu nhập trên 120k/năm
# 6.Về độ tuổi: Hầu hết tệp khách hàng nằm ở độ tuổi trung niên từ hơn 40 tuổi - 52 tuổi
# 7. Về số người phụ thuộc :Số người phụ thuộc của khách hàng phổ biến trong khoảng từ 1-3 người, chỉ có 9% không có người phụ thuộc, và 20% số người có trên 3 người phụ thuộc.Nhóm rời bỏ có số lượng người phụ thuộc trung bình cao hơn nhóm không rời bỏ

# %% [markdown]
# ### Phân tích qua hành vi sử dụng thẻ tín dụng của khách hàng

# %%
# Tạo heatmap
plt.subplots(figsize = (18,18))
sns.heatmap(df_enc.corr(), annot = True, linewidths = 0.2)
# Out:
# <Axes: >

# %% [raw]
# Chúng ta sẽ phân tích các thông tin liên quan đến thẻ của khách hàng gồm những features sau:
# Months_on_book: Biểu thị số tháng mà khách hàng duy trì tài khoản.Cung cấp thông tin về mức độ trung thành và độ dài quan hệ giữa khách hàng và tổ chức tài chính
# Total_Relationship_Count: thể hiện số lượng quan hệ của mỗi khách hàng với ngân hàng. VD:Số lượng tài khoản KH có, khoản vay, số lượng thẻ tín dụng,...
# Credit Limit:chỉ ra giới hạn tín dụng mà khách hàng nhận được
# Avg_Open_To_Buy: số tiền trung bình mà khách hàng có thể sử dụng cho các giao dịch tín dụng mà không vượt quá giới hạn tín dụng của họ.

# %%
# Dependent_count
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Vẽ biểu đồ countplot 
sns.countplot(x='Months_on_book', hue='Label', data=df_encl, palette="RdBu_r", ax=axes[0])

# Vẽ biểu đồ boxplot 
sns.boxplot(data=df_encl, y='Months_on_book', x='Label', palette="RdBu_r", ax=axes[1])

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Vẽ biểu đồ countplot 
sns.countplot(x='Total_Relationship_Count', hue='Label', data=df_encl, palette="RdBu_r", ax=axes[0])

# Vẽ biểu đồ boxplot 
sns.boxplot(data=df_encl, y='Total_Relationship_Count', x='Label', palette="RdBu_r", ax=axes[1])


plt.tight_layout()
plt.show()

df_large_amount = df_encl.groupby("Total_Relationship_Count").agg(num_user=("CLIENTNUM", "count"),num_churn=("Label", "sum"))
df_large_amount["Churn_rate"] = df_large_amount['num_churn']/df_large_amount["num_user"]
df_large_amount
# Out:
#                           num_user  num_churn  Churn_rate
# Total_Relationship_Count
# 1                              627        158    0.251994
# 2                              848        236    0.278302
# 3                             1617        277    0.171305
# 4                             1350        141    0.104444
# 5                             1363        160    0.117388
# 6                             1276        141    0.110502

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

sns.boxplot(data=df_encl, y='Credit_Limit', x='Label', palette="RdBu_r", ax=axes[0])

# Vẽ biểu đồ boxplot 
sns.boxplot(data=df_encl, y='Avg_Open_To_Buy', x='Label', palette="RdBu_r", ax=axes[1])

plt.tight_layout()
plt.show()

# %% [raw]
# Trước khi tiếp tục với bước tiếp theo, ta nhận thấy rằng có tồn tại outliers trong cả  Credit_Limit và Avg_Open_To_buy
# =>Loại bỏ outliers

# %%
cols_visua = ['Credit_Limit','Avg_Open_To_Buy']

fig, ax = plt.subplots(ncols=2, nrows=len(cols_visua), figsize=(16, 5*len(cols_visua)))
                
df_visual = df_encl.copy()

for i, col in enumerate(cols_visua):
    Q3 = df_encl[cols_visua].quantile(0.99)
    df_encl = df_encl[df_encl[cols_visua] <= Q3]
    Q1 = df_encl[cols_visua].quantile(0.01)
    df_encl = df_encl[df_encl[cols_visua] >= Q1]
    # Vẽ KDE plot
    sns.kdeplot(data=df_visual, x=col, fill=True, alpha=1, 
                hue='Label', palette=("RdBu_r"), multiple='stack', ax=ax[i, 0])
    
    # Vẽ Box plot
    sns.boxplot(data=df_visual, y=col, x='Label', ax=ax[i, 1],
                palette=("RdBu_r"))

# Thiết lập tiêu đề cho mỗi biểu đồ
for i, col in enumerate(cols_visua):
    ax[i, 0].set_title(f'KDE Plot of {col}')
    ax[i, 1].set_title(f'Box Plot of {col}')

plt.tight_layout()
plt.show()

# %%
cols_visua = ['Months_Inactive_12_mon','Contacts_Count_12_mon']

fig, ax = plt.subplots(ncols=2, nrows=len(cols_visua), figsize=(16, 5*len(cols_visua)))
                
df_visual = df_encl.copy()

for i, col in enumerate(cols_visua):
    Q3 = df_encl[cols_visua].quantile(0.99)
    df_encl = df_encl[df_encl[cols_visua] <= Q3]
    Q1 = df_encl[cols_visua].quantile(0.01)
    df_encl = df_encl[df_encl[cols_visua] >= Q1]
    # Vẽ KDE plot
    sns.kdeplot(data=df_visual, x=col, fill=True, alpha=1, 
                hue='Label', palette=("RdBu_r"), multiple='stack', ax=ax[i, 0])
    
    # Vẽ Box plot
    sns.boxplot(data=df_visual, y=col, x='Label', ax=ax[i, 1],
                palette=("RdBu_r"))

# Thiết lập tiêu đề cho mỗi biểu đồ
for i, col in enumerate(cols_visua):
    ax[i, 0].set_title(f'KDE Plot of {col}')
    ax[i, 1].set_title(f'Box Plot of {col}')

plt.tight_layout()
plt.show()

# %% [raw]
# Qua việc phân tích về thẻ tín dụng của khách hàng ta nhận ra những điểm sau:
# 1. Feature Total_Relationship_Count có ý nghĩa liên quan đến việc khách hàng rời bỏ. Nhìn vào tỷ lệ ta thấy những khách hàng sử ít hơn 3 dịch vụ của ngân hàng có tỷ lệ rời bỏ cao hơn gấp đôi so với những khách hàng khác
# => Điều này cho thấy rằng độ trung thành của khách hàng liên quan đến số lượng dịch vụ mà khách hàng sử dụng do ngân hàng cung cấp
# 2. Credit_Limit và Avg_Open_To_Buy: có corr là 1, chúng có sự thay đổi giống nhau => Ta có thể null 1 cột

# %% [raw]
# Sau khi phân tích những features liên quan đến thẻ của khách hàng. Ta sẽ phân tích những feature còn lại liên quan đến các giao dịch của khách hàng:
#  Months_Inactive_12_mon: số tháng mà một khách hàng không thực hiện bất kỳ giao dịch nào trên tài khoản của họ trong vòng 12 tháng qua
#  Contacts_Count_12_mon: số lần mà một khách hàng đã tương tác với ngân hàng qua các kênh khác nhau trong vòng 12 tháng
#  Total_Revolving_Bal: Tổng tín dụng quay vòng.
#  Avg_Utilization_Ratio: : Tỷ lệ chi tiêu thẻtrung bình (Số tiền đã sử dụng/Hạn mức tín dụng).
#  Total_Amt_Chng_Q4_Q1:sự thay đổi tổng số tiền giao dịch giữa quý 4 và quý 1.
#  Total_Trans_Amt:tổng số tiền giao dịch mà khách hàng đã thực hiện
#  Total_Trans_Ct: Tổng số giao dịch mà khách hàng đã thực hiện
#  Total_Ct_Chng_Q4_Q1: Sự thay đổi giữa lượng giao dịch giữa quý 4 và quý 1

# %%
df_encl.columns
# Out:
# Index(['CLIENTNUM', 'Label', 'Customer_Age', 'Gender', 'Dependent_count',
#        'Education_Level', 'Marital_Status', 'Income_Category', 'Card_Category',
#        'Months_on_book', 'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio'],
#       dtype='object')

# %%
print(df_encl.groupby(['Months_Inactive_12_mon']).agg(Attrition_Flag=('Label', 'mean')).reset_index())
print(df_encl.groupby(['Contacts_Count_12_mon']).agg(Attrition_Flag=('Label', 'mean')).reset_index())
# Out:
#    Months_Inactive_12_mon  Attrition_Flag
# 0                       0        0.473684
# 1                       1        0.042623
# 2                       2        0.150000
# 3                       3        0.209251
# 4                       4        0.304498
# 5                       5        0.170543
# 6                       6        0.146667
#    Contacts_Count_12_mon  Attrition_Flag
# 0                      0        0.017361
# 1                      1        0.077745
# 2                      2        0.119331
# 3                      3        0.199235
# 4                      4        0.219836
# 5                      5        0.328244
# 6                      6        1.000000

# %% [raw]
# Nhận xét:
# 1.Tỷ lệ khách hàng churn nếu không có bất kì hoạt động nào ở tháng 3-4 là cao nhất, tuy nhiên ở đây phần lớn khách hàng churn thuộc nhóm không hoạt động 2-3 tháng
# 2.Số lần mà khách hàng tương tác với ngân hàng càng tăng lên thì tỷ lệ churn càng cao có thể do phàn nàn, phản ánh,... nói chung là tiêu cực
# 3.Tỷ lệ sử dụng thẻ tín dụng có vẻ như tỷ lệ churn khách hàng thấp hơn là sử dụng

# %%
cols_visua = ['Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt','Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1']

fig, ax = plt.subplots(ncols=2, nrows=len(cols_visua), figsize=(16, 5*len(cols_visua)))
                
df_visual = df_encl.copy()

for i, col in enumerate(cols_visua):
    Q3 = df_encl[col].quantile(0.99)
    df_encl = df_encl[df_encl[col] <= Q3]
    Q1 = df_encl[col].quantile(0.01)
    df_encl = df_encl[df_encl[col] >= Q1]
    # Vẽ KDE plot
    sns.kdeplot(data=df_visual, x=col, fill=True, alpha=1, 
                hue='Label', palette=("RdBu_r"), multiple='stack', ax=ax[i, 0])
    
    # Vẽ Box plot
    sns.boxplot(data=df_visual, y=col, x='Label', ax=ax[i, 1],
                palette=("RdBu_r"))

# Thiết lập tiêu đề cho mỗi biểu đồ
for i, col in enumerate(cols_visua):
    ax[i, 0].set_title(f'KDE Plot of {col}')
    ax[i, 1].set_title(f'Box Plot of {col}')

plt.tight_layout()
plt.show()

# %% [raw]
# Nhận xét:
# 1. Tổng giao dịch giữa quý 4 và 1: Q1 sẽ giảm tiêu dùng hơn Q4
# 2. Có thể thấy tỷ lệ customer churn thấp hơn và không có sự giảm đột ngột

# %%
# Drop cột clientnum vì nó không có ý nghĩa
df_enc = df_enc.drop(columns = ['CLIENTNUM'])

# %% [raw]
# Feature Selection: Chọn lọc và loại bỏ những features không liên quan => giảm độ phức tạp cho mô hình
# Chúng ta sẽ sử dụng model XGBoost để xếp loại những feature quan trọng

# %%
# !pip install xgboost

# %%
import xgboost as xgb
model = xgb.XGBClassifier()

x = df_enc.drop(columns = 'Label')
y = df_enc['Label']
model.fit(x, y)

plt.rcParams['figure.figsize'] = (10,5)
xgb.plot_importance(model, importance_type = 'weight')
plt.show()

# %% [raw]
# Sau khi tìm hiểu về dữ liệu, Ta có thể dự đoán một số nguyên nhân khiến khách hàng rời bỏ:
# 1. Do dịch vụ của bên ngân hàng với khách hàng đang mắc lỗi hoặc có nhiều trục trặc dẫn tới số lần khách hàng liên hệ với ngân hàng càng nhiều thì khách hàng sẽ rời bỏ
# 2. Do số tháng khách hàng không hoạt động thẻ tín dụng càng ít thì xác suất rời bỏ dịch vụ càng cao
# 3. Thu nhập khách hàng và Số người phụ thuộc ảnh hưởng đến quyết định đó
# 4. Số lần hay tổng giao dịch của khách hàng còn ít không liên tục => Khách hàng rời bỏ
# => Nhìn chung, khách hàng rời bỏ theo tự nhiên chứ khoogn phải do  các sự kiện tiêu cực trên phương tiện truyền thông ảnh hưởng đến hình ảnh của doanh nghiệp hay Khách hàng rời bỏ để chuyển sang đối thủ cạnh tranh.
# => chúng ta cần đưa ra giải pháp từ chính trong dịch vụ và công ty của mình

# %%
# Xóa cột - không có ý nghĩa và cần thiết để chạy modeling
# Xóa cột AVg_Open_To_Buy: vì có cor với cột Credit_Limit = 1 và có mức ý nghĩa < cột Credit_Limit
df_enc.drop(columns = ['Avg_Open_To_Buy'])
# Out:
#        Label  Customer_Age  Gender  Dependent_count  Education_Level  \
# 0          0            45       1                3                1
# 1          0            49       2                5                2
# 2          0            51       1                3                2
# 4          0            40       1                3                3
# 5          0            44       1                2                2
# ...      ...           ...     ...              ...              ...
# 10120      0            54       1                1                1
# 10121      0            56       2                1                2
# 10122      0            50       1                2                2
# 10124      1            44       2                1                1
# 10126      1            43       2                2                2
#
#        Marital_Status  Income_Category  Card_Category  Months_on_book  \
# ...

# %% [markdown]
# # The Model

# %% [raw]
# Now that we've cleaned up and engineered our data a little, let's try to feed it into a logistic regression model

# %%
df_enc.columns
# Out:
# Index(['Label', 'Customer_Age', 'Gender', 'Dependent_count', 'Education_Level',
#        'Marital_Status', 'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio'],
#       dtype='object')

# %%
df_eng = df_enc.copy()

# %%
y = df_eng[['Label']]
df_x = df_eng.iloc[:,1:18]
df_x
# Out:
#        Customer_Age  Gender  Dependent_count  Education_Level  Marital_Status  \
# 0                45       1                3                1               1
# 1                49       2                5                2               2
# 2                51       1                3                2               1
# 4                40       1                3                3               1
# 5                44       1                2                2               1
# ...             ...     ...              ...              ...             ...
# 10120            54       1                1                1               2
# 10121            56       2                1                2               2
# 10122            50       1                2                2               2
# 10124            44       2                1                1               1
# 10126            43       2                2                2               1
#
# ...

# %% [raw]
# The next step helps scale the features down to a value between the munimum and maximum values in that feature/column. You can find more information about scikit-learn

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
scaler = MinMaxScaler()
x = scaler.fit_transform(df_x)
x.shape
# Out:
# (7081, 17)

# %%
sns.countplot(x = df_enc['Label'],data = df_enc)
# Out:
# <Axes: xlabel='Label', ylabel='count'>

# %% [raw]
# Ta nhận thấy có sự unbalance trong cột Label. Nếu chúng ta sử dụng trực tiếp tập dữ liệu mất cân bằng để đào tạo, mặc dù độ chính xác tổng thể của mô hình cao, nhưng các mẫu thiểu số dễ học không đầy đủ, dẫn đến độ chính xác phân loại của các mẫu thiểu số thấp và tổn thất do đánh giá sai các mẫu thiểu số nghiêm trọng hơn nhiều so với tổn thất do các mẫu đa số gây ra, vì vậy chúng ta nên cân bằng tập dữ liệu.

# %%
from imblearn.under_sampling import RandomUnderSampler
from sklearn.model_selection import train_test_split
import warnings
import plotly.express as px

warnings.simplefilter(action='ignore', category=FutureWarning)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

print("Before undersampling - 0s: ", y_train[y_train['Label']==0].count())
print("Before undersampling - 1s: ", y_train[y_train['Label']==1].count())
undersample = RandomUnderSampler(sampling_strategy='majority')
X_train_under, y_train_under = undersample.fit_resample(X_train, y_train)
print("After undersampling - 0s: ", y_train_under[y_train_under['Label']==0].count())
print("After undersampling - 1s: ", y_train_under[y_train_under['Label']==1].count())
scaled_inputs = X_train_under
targets = y_train_under
fig  = px.histogram(targets, x="Label", color="Label")
fig.show()
# Out:
# Before undersampling - 0s:  Label    4151
# dtype: int64
# Before undersampling - 1s:  Label    805
# dtype: int64
# After undersampling - 0s:  Label    805
# dtype: int64
# After undersampling - 1s:  Label    805
# dtype: int64
# ...

# %%
sắp xếp bảng theo cột Odds_ratio theo thứ tự giảm dần, giúp dễ dàng nhìn thấy những biến có tác động mạnh nhất đến xác suất xảy ra sự kiện trong mô hình hồi quy logistic.

# %% [markdown]
# #### Logistic Regression

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score
import pandas as pd
import numpy as np

y_train_under = y_train_under.values.ravel()  

print(f"y_train_under shape after ravel: {y_train_under.shape}")

rf_model = RandomForestClassifier(n_estimators=100, max_depth=5, min_samples_leaf=10, min_samples_split=20, random_state=0)
rf_model.fit(X_train_under, y_train_under)

y_pred_rf = rf_model.predict(X_train_under)

print(classification_report(y_train_under, y_pred_rf))

accuracy_rf = accuracy_score(y_train_under, y_pred_rf)
print(f'Accuracy: {accuracy_rf:.2f}')

#Tính toán độ quan trọng của các biến
feature_importances = rf_model.feature_importances_
features = df_x.columns

importances_df_rf = pd.DataFrame({
    'Feature': features,
    'Importance': feature_importances
})

importances_df_rf = importances_df_rf.sort_values(by='Importance', ascending=False).reset_index(drop=True)

print(importances_df_rf)
# Out:
# y_train_under shape after ravel: (1610,)
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.93       805
#            1       0.92      0.93      0.93       805
#
#     accuracy                           0.93      1610
#    macro avg       0.93      0.93      0.93      1610
# weighted avg       0.93      0.93      0.93      1610
#
# Accuracy: 0.93
#                      Feature  Importance
# 0             Total_Trans_Ct    0.271330
# 1        Total_Revolving_Bal    0.233553
# 2            Total_Trans_Amt    0.218285
# 3   Total_Relationship_Count    0.062374
# 4       Total_Amt_Chng_Q4_Q1    0.055363
# 5     Months_Inactive_12_mon    0.051274
# 6               Credit_Limit    0.027980
# 7            Avg_Open_To_Buy    0.024272
# 8      Contacts_Count_12_mon    0.017107
# 9               Customer_Age    0.013736
# 10            Months_on_book    0.010167
# 11                    Gender    0.004276
# ...

# %% [markdown]
# ### Decision

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, accuracy_score
import pandas as pd


tree_model = DecisionTreeClassifier(max_depth=5, min_samples_leaf=10, min_samples_split=20, random_state=0)
tree_model.fit(X_train_under, y_train_under)

y_pred_tree = tree_model.predict(X_train_under)

print(classification_report(y_train_under, y_pred_tree))

accuracy_tree = accuracy_score(y_train_under, y_pred_tree)
print(f'Accuracy: {accuracy_tree:.2f}')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91       805
#            1       0.90      0.94      0.92       805
#
#     accuracy                           0.92      1610
#    macro avg       0.92      0.92      0.92      1610
# weighted avg       0.92      0.92      0.92      1610
#
# Accuracy: 0.92

# %%
# Bước 2: Tính toán độ quan trọng của các biến
feature_importances = tree_model.feature_importances_
features = df_x.columns

importances_df = pd.DataFrame({
    'Feature': features,
    'Importance': feature_importances
})

importances_df = importances_df.sort_values(by='Importance', ascending=False).reset_index(drop=True)

print(importances_df)
# Out:
#                      Feature  Importance
# 0             Total_Trans_Ct    0.553492
# 1            Total_Trans_Amt    0.213405
# 2        Total_Revolving_Bal    0.117535
# 3   Total_Relationship_Count    0.057754
# 4     Months_Inactive_12_mon    0.033765
# 5       Total_Amt_Chng_Q4_Q1    0.020638
# 6      Contacts_Count_12_mon    0.002427
# 7               Credit_Limit    0.000984
# 8             Marital_Status    0.000000
# 9            Income_Category    0.000000
# 10             Card_Category    0.000000
# 11            Months_on_book    0.000000
# 12                    Gender    0.000000
# 13           Education_Level    0.000000
# 14           Avg_Open_To_Buy    0.000000
# 15           Dependent_count    0.000000
# 16              Customer_Age    0.000000

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score
import pandas as pd

y_train_under = y_train_under.values.ravel()  # Hoặc sử dụng flatten()

rf_model = RandomForestClassifier(n_estimators=100, max_depth=5, min_samples_leaf=10, min_samples_split=20, random_state=0)
rf_model.fit(X_train_under, y_train_under)

y_pred_rf = rf_model.predict(X_train_under)

print(classification_report(y_train_under, y_pred_rf))

accuracy_rf = accuracy_score(y_train_under, y_pred_rf)
print(f'Accuracy: {accuracy_rf:.2f}')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.93       805
#            1       0.93      0.95      0.94       805
#
#     accuracy                           0.94      1610
#    macro avg       0.94      0.94      0.94      1610
# weighted avg       0.94      0.94      0.94      1610
#
# Accuracy: 0.94

# %%
# Tính toán độ quan trọng của các biến
feature_importances = rf_model.feature_importances_
features = df_x.columns

importances_df_rf = pd.DataFrame({
    'Feature': features,
    'Importance': feature_importances
})

importances_df_rf = importances_df_rf.sort_values(by='Importance', ascending=False).reset_index(drop=True)

print(importances_df_rf)
# Out:
#                      Feature  Importance
# 0             Total_Trans_Ct    0.284459
# 1            Total_Trans_Amt    0.237645
# 2        Total_Revolving_Bal    0.206092
# 3       Total_Amt_Chng_Q4_Q1    0.068808
# 4   Total_Relationship_Count    0.059332
# 5     Months_Inactive_12_mon    0.032365
# 6            Avg_Open_To_Buy    0.029718
# 7               Credit_Limit    0.026768
# 8      Contacts_Count_12_mon    0.018005
# 9               Customer_Age    0.010652
# 10            Months_on_book    0.008624
# 11                    Gender    0.005006
# 12           Dependent_count    0.003545
# 13            Marital_Status    0.003527
# 14           Education_Level    0.002485
# 15           Income_Category    0.002288
# 16             Card_Category    0.000681

# %% [raw]
# Sau khi sử dụng 3 model trên ta thấy rằng model RandomForest có tỷ lệ chính xác cao nhất.
# Và dựa vào bảng importances_df_rf:
# 1.Các thuộc tính thuộc về tín dụng của khách hàng thì sẽ có tác động nhiều đến quyết định rời bỏ sử dụng dịch vụ tín dụng hay không hơn là các thuộc tính liên quan đến nhân khẩu học
# 2.Nguyên nhân khách hàng rời bỏ sử dụng thẻ tín dụng:
#     2.1.Do việc sử dụng không thường xuyên dịch vụ của ngân hàng => khách hàng dễ rời bỏ
#     2.2.Tổng số sản phẩm khách hàng sử dụng của ngân hàng cũng ảnh hưởng đến customer churn => Khách hàng càng sử dụng nhiều dịch vụ của ngân hàng sẽ trung thành hơn
#     2.3.User không hoạt động trong 2-3 tháng có dấu hiệu rời bỏ cao nhất.
#     2.4.Số lượng phản hồi của khách hàng càng cao => tỷ lệ churn càng cao

# %% [raw]
# Giải pháp đưa ra:
#     2.1. Với khách hàng sử dụng không thường xuyên
#          2.1.1.Khuyến khích sử dụng thẻ nhiều hơn bằng cách cung cấp các chương trình khuyến mãi đặc biệt
#          2.1.2. Thường xuyên gửi thông báo cho khách hàng trên điện thoại để khách hàng luôn nhớ và để ý đến
#          2.1.3.Mở rộng các tiện ích khác có thể thanh toán qua credit card
#     2.2.
#          2.2.1. Tăng Cường Sự Đa Dạng Dịch vụ
#     2.3
#          2.3.1.Theo dõi và Tương tác với Khách hàng không Hoạt động
#          2.3.2. Khảo sát khách hàng, quảng cáo về dịch vụ
#     2.4.
#          2.4.1. Cải thiện chất lượng của dịch vụ
#          2.4.2. Thường xuyên tạo khảo sát về những ưu điểm và nhược điểm
#          2.4.3. Gọi điện chăm sóc khách hàng
